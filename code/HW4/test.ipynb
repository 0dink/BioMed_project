# %%
import os
import numpy as np
import soundfile as sf
from scipy.ndimage import gaussian_filter1d
import pandas as pd
import noisereduce as nr
import csv

# %%
def get_filenames_by_lowest_subfolder(root_folder, x):
    file_dict = {}
    
    # Get the subdirectories of the root folder and sort them numerically
    subfolders = [subfolder for subfolder in os.listdir(root_folder) 
                  if os.path.isdir(os.path.join(root_folder, subfolder))]
    
    # Sort subfolders numerically if they are numbers, otherwise as strings
    subfolders.sort(key=lambda name: int(name) if name.isdigit() else name)
    
    # Limit to the first x subfolders
    subfolders = subfolders[:x]
    
    # Walk through each selected subfolder
    for subfolder in subfolders:
        subfolder_path = os.path.join(root_folder, subfolder)
        
        for dirpath, _, filenames in os.walk(subfolder_path):
            if filenames:  # If there are files in the directory
                # Get the last folder in the current path as the lowest subfolder
                lowest_subfolder = os.path.basename(dirpath)
                
                # Initialize the list for the lowest subfolder if it doesn't exist
                if lowest_subfolder not in file_dict:
                    file_dict[lowest_subfolder] = []
                
                # Add files to the respective lowest subfolder
                for filename in filenames:
                    if filename.endswith(".flac"):
                        full_file_path = os.path.join(dirpath, filename)
                        file_dict[lowest_subfolder].append(full_file_path)
    
    return file_dict

# %%
def estimate_snr_weighted(audio_signal, base_sigma=1.2, min_segment_length=500, max_segment_length=1500, adaptive_factor=0.01):
    """
    Estimating the Signal-to-Noise Ratio (SNR) of a given speech signal using weighted adaptive smoothing,
    dynamic segment lengths, and signal power scaling for higher SNR.
    """
    if len(audio_signal.shape) > 1:
        audio_signal = np.mean(audio_signal, axis=1)

    normalized_signal = audio_signal / np.max(np.abs(audio_signal))
    power_signal = np.mean(normalized_signal ** 2)
    max_signal_value = np.max(np.abs(normalized_signal))
    adaptive_noise_threshold = adaptive_factor * max_signal_value

    smoothed_signal = np.zeros_like(normalized_signal)
    total_samples = len(normalized_signal)
    pos = 0

    while pos < total_samples:
        segment_length = np.random.randint(min_segment_length, max_segment_length)
        end = min(pos + segment_length, total_samples)
        segment = normalized_signal[pos:end]
        segment_power = np.abs(segment).mean()

        if segment_power < adaptive_noise_threshold:
            local_sigma = base_sigma + 3
        else:
            local_sigma = base_sigma

        smoothed_signal[pos:end] = gaussian_filter1d(segment, sigma=local_sigma)
        pos = end

    noise = normalized_signal - smoothed_signal
    power_noise = np.mean(noise ** 2)
    snr = 10 * np.log10(power_signal / power_noise)

    return snr

# %%
def filter_and_snr(audio_signal, sample_rate):
    
    snr_estimated = estimate_snr_weighted(audio_signal)
    denoised_audio_signal = nr.reduce_noise(y=audio_signal, sr=sample_rate, prop_decrease=0.8)
    snr_estimated_cleaned = estimate_snr_weighted(denoised_audio_signal)

    return(snr_estimated, snr_estimated_cleaned, denoised_audio_signal)

# %%
root_directory = r"C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\LibriSpeech\train-clean-100"
save_to_dir = r"C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned"
SAMPLE_RATE = 16000

x = 1  # Change this to the number of subfolders you want to limit to
files_by_lowest_subfolder = get_filenames_by_lowest_subfolder(root_directory, x)

for lowest_subfolder, files in files_by_lowest_subfolder.items():
    print(f"Lowest Subfolder: {lowest_subfolder}")
    
    
    denoised_file_paths = []
    densoised_to_save = []
    
    snr_data = []

    for file in files:
        relative_path = os.path.relpath(file, root_directory)
        print(relative_path)
        filename, _ = os.path.splitext(relative_path)
        print(filename)
        save_to = os.path.join(save_to_dir, filename + ".wav")
        print(save_to)
        audio_signal, _ = sf.read(file)
        
        snr_estimated, snr_estimated_cleaned, denoised_audio_signal = filter_and_snr(audio_signal, SAMPLE_RATE)
        
        snr_data.append([filename, snr_estimated, snr_estimated_cleaned])

        denoised_file_paths.append(save_to)
        densoised_to_save.append(denoised_audio_signal)
        
        # print(snr_estimated, snr_estimated_cleaned)

    print(f"saving subfolder: {lowest_subfolder}")
    
    with open('../../data/output/snr_data.csv', mode='a', newline='') as file:
        writer = csv.writer(file)
        writer.writerows(snr_data)

    for save_to, denoised_audio_signal in zip(denoised_file_paths, densoised_to_save):
        sf.write(save_to, np.asarray(denoised_audio_signal), SAMPLE_RATE)
# Out:
# Lowest Subfolder: 198
# 19\198\19-198-0000.flac
# 19\198\19-198-0000
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\198\19-198-0000.wav
# 19\198\19-198-0001.flac
# 19\198\19-198-0001
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\198\19-198-0001.wav
# 19\198\19-198-0002.flac
# 19\198\19-198-0002
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\198\19-198-0002.wav
# 19\198\19-198-0003.flac
# 19\198\19-198-0003
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\198\19-198-0003.wav
# 19\198\19-198-0004.flac
# 19\198\19-198-0004
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\198\19-198-0004.wav
# 19\198\19-198-0005.flac
# 19\198\19-198-0005
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\198\19-198-0005.wav
# 19\198\19-198-0006.flac
# 19\198\19-198-0006
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\198\19-198-0006.wav
# 19\198\19-198-0007.flac
# 19\198\19-198-0007
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\198\19-198-0007.wav
# 19\198\19-198-0008.flac
# 19\198\19-198-0008
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\198\19-198-0008.wav
# 19\198\19-198-0009.flac
# 19\198\19-198-0009
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\198\19-198-0009.wav
# 19\198\19-198-0010.flac
# 19\198\19-198-0010
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\198\19-198-0010.wav
# 19\198\19-198-0011.flac
# 19\198\19-198-0011
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\198\19-198-0011.wav
# 19\198\19-198-0012.flac
# 19\198\19-198-0012
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\198\19-198-0012.wav
# 19\198\19-198-0013.flac
# 19\198\19-198-0013
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\198\19-198-0013.wav
# 19\198\19-198-0014.flac
# 19\198\19-198-0014
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\198\19-198-0014.wav
# 19\198\19-198-0015.flac
# 19\198\19-198-0015
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\198\19-198-0015.wav
# 19\198\19-198-0016.flac
# 19\198\19-198-0016
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\198\19-198-0016.wav
# 19\198\19-198-0017.flac
# 19\198\19-198-0017
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\198\19-198-0017.wav
# 19\198\19-198-0018.flac
# 19\198\19-198-0018
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\198\19-198-0018.wav
# 19\198\19-198-0019.flac
# 19\198\19-198-0019
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\198\19-198-0019.wav
# 19\198\19-198-0020.flac
# 19\198\19-198-0020
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\198\19-198-0020.wav
# 19\198\19-198-0021.flac
# 19\198\19-198-0021
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\198\19-198-0021.wav
# 19\198\19-198-0022.flac
# 19\198\19-198-0022
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\198\19-198-0022.wav
# 19\198\19-198-0023.flac
# 19\198\19-198-0023
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\198\19-198-0023.wav
# 19\198\19-198-0024.flac
# 19\198\19-198-0024
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\198\19-198-0024.wav
# 19\198\19-198-0025.flac
# 19\198\19-198-0025
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\198\19-198-0025.wav
# 19\198\19-198-0026.flac
# 19\198\19-198-0026
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\198\19-198-0026.wav
# 19\198\19-198-0027.flac
# 19\198\19-198-0027
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\198\19-198-0027.wav
# 19\198\19-198-0028.flac
# 19\198\19-198-0028
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\198\19-198-0028.wav
# 19\198\19-198-0029.flac
# 19\198\19-198-0029
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\198\19-198-0029.wav
# 19\198\19-198-0030.flac
# 19\198\19-198-0030
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\198\19-198-0030.wav
# 19\198\19-198-0031.flac
# 19\198\19-198-0031
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\198\19-198-0031.wav
# 19\198\19-198-0032.flac
# 19\198\19-198-0032
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\198\19-198-0032.wav
# 19\198\19-198-0033.flac
# 19\198\19-198-0033
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\198\19-198-0033.wav
# 19\198\19-198-0034.flac
# 19\198\19-198-0034
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\198\19-198-0034.wav
# 19\198\19-198-0035.flac
# 19\198\19-198-0035
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\198\19-198-0035.wav
# 19\198\19-198-0036.flac
# 19\198\19-198-0036
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\198\19-198-0036.wav
# 19\198\19-198-0037.flac
# 19\198\19-198-0037
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\198\19-198-0037.wav
# saving subfolder: 198
# Lowest Subfolder: 227
# 19\227\19-227-0000.flac
# 19\227\19-227-0000
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\227\19-227-0000.wav
# 19\227\19-227-0001.flac
# 19\227\19-227-0001
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\227\19-227-0001.wav
# 19\227\19-227-0002.flac
# 19\227\19-227-0002
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\227\19-227-0002.wav
# 19\227\19-227-0003.flac
# 19\227\19-227-0003
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\227\19-227-0003.wav
# 19\227\19-227-0004.flac
# 19\227\19-227-0004
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\227\19-227-0004.wav
# 19\227\19-227-0005.flac
# 19\227\19-227-0005
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\227\19-227-0005.wav
# 19\227\19-227-0006.flac
# 19\227\19-227-0006
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\227\19-227-0006.wav
# 19\227\19-227-0007.flac
# 19\227\19-227-0007
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\227\19-227-0007.wav
# 19\227\19-227-0008.flac
# 19\227\19-227-0008
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\227\19-227-0008.wav
# 19\227\19-227-0009.flac
# 19\227\19-227-0009
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\227\19-227-0009.wav
# 19\227\19-227-0010.flac
# 19\227\19-227-0010
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\227\19-227-0010.wav
# 19\227\19-227-0011.flac
# 19\227\19-227-0011
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\227\19-227-0011.wav
# 19\227\19-227-0012.flac
# 19\227\19-227-0012
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\227\19-227-0012.wav
# 19\227\19-227-0013.flac
# 19\227\19-227-0013
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\227\19-227-0013.wav
# 19\227\19-227-0014.flac
# 19\227\19-227-0014
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\227\19-227-0014.wav
# 19\227\19-227-0015.flac
# 19\227\19-227-0015
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\227\19-227-0015.wav
# 19\227\19-227-0016.flac
# 19\227\19-227-0016
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\227\19-227-0016.wav
# 19\227\19-227-0017.flac
# 19\227\19-227-0017
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\227\19-227-0017.wav
# 19\227\19-227-0018.flac
# 19\227\19-227-0018
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\227\19-227-0018.wav
# 19\227\19-227-0019.flac
# 19\227\19-227-0019
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\227\19-227-0019.wav
# 19\227\19-227-0020.flac
# 19\227\19-227-0020
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\227\19-227-0020.wav
# 19\227\19-227-0021.flac
# 19\227\19-227-0021
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\227\19-227-0021.wav
# 19\227\19-227-0022.flac
# 19\227\19-227-0022
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\227\19-227-0022.wav
# 19\227\19-227-0023.flac
# 19\227\19-227-0023
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\227\19-227-0023.wav
# 19\227\19-227-0024.flac
# 19\227\19-227-0024
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\227\19-227-0024.wav
# 19\227\19-227-0025.flac
# 19\227\19-227-0025
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\227\19-227-0025.wav
# 19\227\19-227-0026.flac
# 19\227\19-227-0026
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\227\19-227-0026.wav
# 19\227\19-227-0027.flac
# 19\227\19-227-0027
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\227\19-227-0027.wav
# 19\227\19-227-0028.flac
# 19\227\19-227-0028
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\227\19-227-0028.wav
# 19\227\19-227-0029.flac
# 19\227\19-227-0029
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\227\19-227-0029.wav
# 19\227\19-227-0030.flac
# 19\227\19-227-0030
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\227\19-227-0030.wav
# 19\227\19-227-0031.flac
# 19\227\19-227-0031
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\227\19-227-0031.wav
# 19\227\19-227-0032.flac
# 19\227\19-227-0032
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\227\19-227-0032.wav
# 19\227\19-227-0033.flac
# 19\227\19-227-0033
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\227\19-227-0033.wav
# 19\227\19-227-0034.flac
# 19\227\19-227-0034
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\227\19-227-0034.wav
# 19\227\19-227-0035.flac
# 19\227\19-227-0035
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\227\19-227-0035.wav
# 19\227\19-227-0036.flac
# 19\227\19-227-0036
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\227\19-227-0036.wav
# 19\227\19-227-0037.flac
# 19\227\19-227-0037
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\227\19-227-0037.wav
# 19\227\19-227-0038.flac
# 19\227\19-227-0038
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\227\19-227-0038.wav
# 19\227\19-227-0039.flac
# 19\227\19-227-0039
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\227\19-227-0039.wav
# 19\227\19-227-0040.flac
# 19\227\19-227-0040
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\227\19-227-0040.wav
# 19\227\19-227-0041.flac
# 19\227\19-227-0041
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\227\19-227-0041.wav
# 19\227\19-227-0042.flac
# 19\227\19-227-0042
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\227\19-227-0042.wav
# 19\227\19-227-0043.flac
# 19\227\19-227-0043
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\227\19-227-0043.wav
# 19\227\19-227-0044.flac
# 19\227\19-227-0044
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\227\19-227-0044.wav
# 19\227\19-227-0045.flac
# 19\227\19-227-0045
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\227\19-227-0045.wav
# 19\227\19-227-0046.flac
# 19\227\19-227-0046
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\227\19-227-0046.wav
# 19\227\19-227-0047.flac
# 19\227\19-227-0047
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\227\19-227-0047.wav
# 19\227\19-227-0048.flac
# 19\227\19-227-0048
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\227\19-227-0048.wav
# 19\227\19-227-0049.flac
# 19\227\19-227-0049
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\227\19-227-0049.wav
# 19\227\19-227-0050.flac
# 19\227\19-227-0050
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\227\19-227-0050.wav
# 19\227\19-227-0051.flac
# 19\227\19-227-0051
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\227\19-227-0051.wav
# 19\227\19-227-0052.flac
# 19\227\19-227-0052
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\227\19-227-0052.wav
# 19\227\19-227-0053.flac
# 19\227\19-227-0053
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\227\19-227-0053.wav
# 19\227\19-227-0054.flac
# 19\227\19-227-0054
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\227\19-227-0054.wav
# 19\227\19-227-0055.flac
# 19\227\19-227-0055
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\227\19-227-0055.wav
# 19\227\19-227-0056.flac
# 19\227\19-227-0056
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\227\19-227-0056.wav
# 19\227\19-227-0057.flac
# 19\227\19-227-0057
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\227\19-227-0057.wav
# 19\227\19-227-0058.flac
# 19\227\19-227-0058
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\227\19-227-0058.wav
# 19\227\19-227-0059.flac
# 19\227\19-227-0059
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\227\19-227-0059.wav
# 19\227\19-227-0060.flac
# 19\227\19-227-0060
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\227\19-227-0060.wav
# 19\227\19-227-0061.flac
# 19\227\19-227-0061
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\227\19-227-0061.wav
# 19\227\19-227-0062.flac
# 19\227\19-227-0062
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\227\19-227-0062.wav
# 19\227\19-227-0063.flac
# 19\227\19-227-0063
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\227\19-227-0063.wav
# 19\227\19-227-0064.flac
# 19\227\19-227-0064
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\227\19-227-0064.wav
# 19\227\19-227-0065.flac
# 19\227\19-227-0065
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\227\19-227-0065.wav
# 19\227\19-227-0066.flac
# 19\227\19-227-0066
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\227\19-227-0066.wav
# 19\227\19-227-0067.flac
# 19\227\19-227-0067
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\227\19-227-0067.wav
# 19\227\19-227-0068.flac
# 19\227\19-227-0068
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\227\19-227-0068.wav
# 19\227\19-227-0069.flac
# 19\227\19-227-0069
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\227\19-227-0069.wav
# 19\227\19-227-0070.flac
# 19\227\19-227-0070
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\227\19-227-0070.wav
# 19\227\19-227-0071.flac
# 19\227\19-227-0071
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\227\19-227-0071.wav
# 19\227\19-227-0072.flac
# 19\227\19-227-0072
# C:\Computer Science Programs\Fall_2024\EE502_BioMed\project\data\cleaned\19\227\19-227-0072.wav
# saving subfolder: 227
